# %%
from LMI_API3 import *

# %%
df4
# Out:
#      soc                    region  skill shortage vacancies  \
# 0   2136                    London                        32
# 1   2231                    London                        22
# 2   2231      South East (England)                        30
# 3   2231   West Midlands (England)                        13
# 4   2231  Yorkshire and the Humber                        60
# ..   ...                       ...                       ...
# 92  9274   East Midlands (England)                        13
# 93  9274  Yorkshire and the Humber                        14
# 94  9274      North West (England)                        20
# 95  9274      North East (England)                         2
# 96  9274                     Wales                        17
#
#     hard to find vacancies  reliability
# 0                       34            1
# 1                       36            1
# 2                       60            1
# 3                       82            1
# ...

# %%
df4.head(10)
# Out:
#     soc                    region  skill shortage vacancies  \
# 0  2136                    London                        32
# 1  2231                    London                        22
# 2  2231      South East (England)                        30
# 3  2231   West Midlands (England)                        13
# 4  2231  Yorkshire and the Humber                        60
# 5  2231      North West (England)                        33
# 6  2231                     Wales                        29
# 7  3542                    London                        15
# 8  3542      South East (England)                        28
# 9  3542   West Midlands (England)                        21
#
#    hard to find vacancies  reliability
# 0                      34            1
# 1                      36            1
# 2                      60            1
# 3                      82            1
# 4                      70            1
# 5                      64            1
# ...
