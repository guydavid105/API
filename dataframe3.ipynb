# %%
from LMI_API2 import *
# Out:
# 27393

# %%
df3
# Out:
#                              role       id  \
# 0           Director (government)  6131952
# 1           Director (government)  5746288
# 2           Director (government)  6129844
# 3           Director (government)  6260797
# 4           Director (government)  6095259
# ...                           ...      ...
# 27432       Superintendent, baths        0
# 27433                Phrenologist        0
# 27434  Supervisor, field, playing        0
# 27435                      Medium        0
# 27436           Attendant, hostel        0
#
#                                                    title  \
# 0                                 Director of Governance
# 1                  Group Director of Clinical Governance
# 2      Director of Governance | University Hospitals ...
# 3                   PA to Corporate Governance Directors
# 4      Deputy Director of Quality Governance | Blackp...
# ...                                                  ...
# ...

# %%
df3.tail()
# Out:
#                              role  id              title  \
# 27432       Superintendent, baths   0  Too Many Requests
# 27433                Phrenologist   0  Too Many Requests
# 27434  Supervisor, field, playing   0  Too Many Requests
# 27435                      Medium   0  Too Many Requests
# 27436           Attendant, hostel   0  Too Many Requests
#
#                                                  summary       company
# 27432  We are currently experiencing occasional, very...  NOTIFICATION
# 27433  We are currently experiencing occasional, very...  NOTIFICATION
# 27434  We are currently experiencing occasional, very...  NOTIFICATION
# 27435  We are currently experiencing occasional, very...  NOTIFICATION
# 27436  We are currently experiencing occasional, very...  NOTIFICATION

# %%
df3.tail(100)
# Out:
#                              role  id              title  \
# 27337  Attendant, park, amusement   0  Too Many Requests
# 27338            Attendant, stall   0  Too Many Requests
# 27339          Attendant, theatre   0  Too Many Requests
# 27340               Caller, bingo   0  Too Many Requests
# 27341                Boy, clapper   0  Too Many Requests
# ...                           ...  ..                ...
# 27432       Superintendent, baths   0  Too Many Requests
# 27433                Phrenologist   0  Too Many Requests
# 27434  Supervisor, field, playing   0  Too Many Requests
# 27435                      Medium   0  Too Many Requests
# 27436           Attendant, hostel   0  Too Many Requests
#
#                                                  summary       company
# 27337  We are currently experiencing occasional, very...  NOTIFICATION
# 27338  We are currently experiencing occasional, very...  NOTIFICATION
# ...

# %%
df3.head(50)
# Out:
#                      role       id  \
# 0   Director (government)  6131952
# 1   Director (government)  5746288
# 2   Director (government)  6129844
# 3   Director (government)  6260797
# 4   Director (government)  6095259
# 5   Director (government)  6287144
# 6   Director (government)  6309112
# 7   Director (government)  6263059
# 8   Director (government)  6307982
# 9   Director (government)  6260680
# 10  Director (government)  6272655
# 11  Director (government)  6312665
# 12  Director (government)  6328145
# 13  Director (government)  6287356
# 14  Director (government)  6258583
# 15  Director (government)  6150730
# 16  Director (government)  6125710
# 17  Director (government)  6308225
# 18  Director (government)  6262967
# 19  Director (government)  6192624
# 20  Director (government)  6162199
# 21  Director (government)  6153420
# 22  Director (government)  6260551
# 23  Director (government)  6205727
# 24  Director (government)  6250347
# ...
